# %%
# import all the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# get data
df=pd.read_excel("Honda.xlsx")
df
# Out:
#      Order_ID Order_Date Customer Name         City       Salesperson Region  \
# 0        1001 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 1        1002 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 2        1003 2014-01-04     Company D     New York    Andrew Cencini   East
# 3        1004 2014-01-04     Company D     New York    Andrew Cencini   East
# 4        1005 2014-01-04     Company D     New York    Andrew Cencini   East
# ..        ...        ...           ...          ...               ...    ...
# 384      1067 2014-03-08     Company H     Portland   Nancy Freehafer  North
# 385      1070 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 386      1071 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 387      1075 2014-03-10     Company J      Chicago    Laura Giussani   East
# 388      1077 2014-03-10     Company J      Chicago    Laura Giussani   East
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       389 non-null    int64
#  1   Order_Date     389 non-null    datetime64[ns]
#  2   Customer Name  389 non-null    object
#  3   City           389 non-null    object
#  4   Salesperson    389 non-null    object
#  5   Region         389 non-null    object
#  6   Shipped Date   318 non-null    datetime64[ns]
#  7   Shipper Name   353 non-null    object
#  8   Ship Name      389 non-null    object
#  9   Payment Type   389 non-null    object
#  10  Product Name   389 non-null    object
#  11  Category       389 non-null    object
#  12  Unit Price     385 non-null    float64
#  13  Quantity       386 non-null    float64
# dtypes: datetime64[ns](2), float64(2), int64(1), object(9)
# memory usage: 42.7+ KB

# %%
# total number of rows in dataset
len(df)
# Out:
# 389

# %%
# check for null
df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Customer Name     0
# City              0
# Salesperson       0
# Region            0
# Shipped Date     71
# Shipper Name     36
# Ship Name         0
# Payment Type      0
# Product Name      0
# Category          0
# Unit Price        4
# Quantity          3
# dtype: int64

# %%
pd.isna(df).sum()
# Out:
# Order_ID          0
# Order_Date        0
# Customer Name     0
# City              0
# Salesperson       0
# Region            0
# Shipped Date     71
# Shipper Name     36
# Ship Name         0
# Payment Type      0
# Product Name      0
# Category          0
# Unit Price        4
# Quantity          3
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#      Order_ID Order_Date Customer Name         City       Salesperson Region  \
# 1        1002 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 2        1003 2014-01-04     Company D     New York    Andrew Cencini   East
# 3        1004 2014-01-04     Company D     New York    Andrew Cencini   East
# 6        1007 2014-01-12     Company L    Las Vegas  Mariya Sergienko   West
# 7        1008 2014-01-08     Company H     Portland   Nancy Freehafer  North
# ..        ...        ...           ...          ...               ...    ...
# 367      1431 2014-12-04     Company D     New York    Andrew Cencini   East
# 368      1432 2014-12-03     Company C  Los Angelas  Mariya Sergienko   West
# 369      1050 2014-02-04     Company D     New York    Andrew Cencini   East
# 370      1051 2014-02-03     Company C  Los Angelas  Mariya Sergienko   West
# 388      1077 2014-03-10     Company J      Chicago    Laura Giussani   East
#
# ...

# %%
# cleaning
df["Quantity"]=df.Quantity.fillna(df.Quantity.mean())
df
# Out:
#      Order_ID Order_Date Customer Name         City       Salesperson Region  \
# 0        1001 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 1        1002 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 2        1003 2014-01-04     Company D     New York    Andrew Cencini   East
# 3        1004 2014-01-04     Company D     New York    Andrew Cencini   East
# 4        1005 2014-01-04     Company D     New York    Andrew Cencini   East
# ..        ...        ...           ...          ...               ...    ...
# 384      1067 2014-03-08     Company H     Portland   Nancy Freehafer  North
# 385      1070 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 386      1071 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 387      1075 2014-03-10     Company J      Chicago    Laura Giussani   East
# 388      1077 2014-03-10     Company J      Chicago    Laura Giussani   East
#
# ...

# %%
df["Unit Price"]=df["Unit Price"].fillna(df["Unit Price"].mean())
df
# Out:
#      Order_ID Order_Date Customer Name         City       Salesperson Region  \
# 0        1001 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 1        1002 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 2        1003 2014-01-04     Company D     New York    Andrew Cencini   East
# 3        1004 2014-01-04     Company D     New York    Andrew Cencini   East
# 4        1005 2014-01-04     Company D     New York    Andrew Cencini   East
# ..        ...        ...           ...          ...               ...    ...
# 384      1067 2014-03-08     Company H     Portland   Nancy Freehafer  North
# 385      1070 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 386      1071 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 387      1075 2014-03-10     Company J      Chicago    Laura Giussani   East
# 388      1077 2014-03-10     Company J      Chicago    Laura Giussani   East
#
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Customer Name     0
# City              0
# Salesperson       0
# Region            0
# Shipped Date     71
# Shipper Name     36
# Ship Name         0
# Payment Type      0
# Product Name      0
# Category          0
# Unit Price        0
# Quantity          0
# dtype: int64

# %%
# drop shipped_date
df.drop("Shipped Date",inplace=True,axis=1)

# %%
df
# Out:
#      Order_ID Order_Date Customer Name         City       Salesperson Region  \
# 0        1001 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 1        1002 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 2        1003 2014-01-04     Company D     New York    Andrew Cencini   East
# 3        1004 2014-01-04     Company D     New York    Andrew Cencini   East
# 4        1005 2014-01-04     Company D     New York    Andrew Cencini   East
# ..        ...        ...           ...          ...               ...    ...
# 384      1067 2014-03-08     Company H     Portland   Nancy Freehafer  North
# 385      1070 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 386      1071 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 387      1075 2014-03-10     Company J      Chicago    Laura Giussani   East
# 388      1077 2014-03-10     Company J      Chicago    Laura Giussani   East
#
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Customer Name     0
# City              0
# Salesperson       0
# Region            0
# Shipper Name     36
# Ship Name         0
# Payment Type      0
# Product Name      0
# Category          0
# Unit Price        0
# Quantity          0
# dtype: int64

# %%
df["Shipper Name"]=df["Shipper Name"].fillna(df["Shipper Name"].mode()[0])
df
# Out:
#      Order_ID Order_Date Customer Name         City       Salesperson Region  \
# 0        1001 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 1        1002 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 2        1003 2014-01-04     Company D     New York    Andrew Cencini   East
# 3        1004 2014-01-04     Company D     New York    Andrew Cencini   East
# 4        1005 2014-01-04     Company D     New York    Andrew Cencini   East
# ..        ...        ...           ...          ...               ...    ...
# 384      1067 2014-03-08     Company H     Portland   Nancy Freehafer  North
# 385      1070 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 386      1071 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 387      1075 2014-03-10     Company J      Chicago    Laura Giussani   East
# 388      1077 2014-03-10     Company J      Chicago    Laura Giussani   East
#
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID         0
# Order_Date       0
# Customer Name    0
# City             0
# Salesperson      0
# Region           0
# Shipper Name     0
# Ship Name        0
# Payment Type     0
# Product Name     0
# Category         0
# Unit Price       0
# Quantity         0
# dtype: int64

# %%
df["month"]=df["Order_Date"].dt.month
df
# Out:
#      Order_ID Order_Date Customer Name         City       Salesperson Region  \
# 0        1001 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 1        1002 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 2        1003 2014-01-04     Company D     New York    Andrew Cencini   East
# 3        1004 2014-01-04     Company D     New York    Andrew Cencini   East
# 4        1005 2014-01-04     Company D     New York    Andrew Cencini   East
# ..        ...        ...           ...          ...               ...    ...
# 384      1067 2014-03-08     Company H     Portland   Nancy Freehafer  North
# 385      1070 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 386      1071 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 387      1075 2014-03-10     Company J      Chicago    Laura Giussani   East
# 388      1077 2014-03-10     Company J      Chicago    Laura Giussani   East
#
# ...

# %%
df["month_name"]=df["Order_Date"].dt.month_name()
df
# Out:
#      Order_ID Order_Date Customer Name         City       Salesperson Region  \
# 0        1001 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 1        1002 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 2        1003 2014-01-04     Company D     New York    Andrew Cencini   East
# 3        1004 2014-01-04     Company D     New York    Andrew Cencini   East
# 4        1005 2014-01-04     Company D     New York    Andrew Cencini   East
# ..        ...        ...           ...          ...               ...    ...
# 384      1067 2014-03-08     Company H     Portland   Nancy Freehafer  North
# 385      1070 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 386      1071 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 387      1075 2014-03-10     Company J      Chicago    Laura Giussani   East
# 388      1077 2014-03-10     Company J      Chicago    Laura Giussani   East
#
# ...

# %%
df["day_name"]=df["Order_Date"].dt.day_name()
df
# Out:
#      Order_ID Order_Date Customer Name         City       Salesperson Region  \
# 0        1001 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 1        1002 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 2        1003 2014-01-04     Company D     New York    Andrew Cencini   East
# 3        1004 2014-01-04     Company D     New York    Andrew Cencini   East
# 4        1005 2014-01-04     Company D     New York    Andrew Cencini   East
# ..        ...        ...           ...          ...               ...    ...
# 384      1067 2014-03-08     Company H     Portland   Nancy Freehafer  North
# 385      1070 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 386      1071 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 387      1075 2014-03-10     Company J      Chicago    Laura Giussani   East
# 388      1077 2014-03-10     Company J      Chicago    Laura Giussani   East
#
# ...

# %%
df["Quarter"]=df["Order_Date"].dt.quarter
df
# Out:
#      Order_ID Order_Date Customer Name         City       Salesperson Region  \
# 0        1001 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 1        1002 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 2        1003 2014-01-04     Company D     New York    Andrew Cencini   East
# 3        1004 2014-01-04     Company D     New York    Andrew Cencini   East
# 4        1005 2014-01-04     Company D     New York    Andrew Cencini   East
# ..        ...        ...           ...          ...               ...    ...
# 384      1067 2014-03-08     Company H     Portland   Nancy Freehafer  North
# 385      1070 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 386      1071 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 387      1075 2014-03-10     Company J      Chicago    Laura Giussani   East
# 388      1077 2014-03-10     Company J      Chicago    Laura Giussani   East
#
# ...

# %%
# set decimal place upto 2 digit
pd.set_option("display.precision",2)

# %%
df
# Out:
#      Order_ID Order_Date Customer Name         City       Salesperson Region  \
# 0        1001 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 1        1002 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 2        1003 2014-01-04     Company D     New York    Andrew Cencini   East
# 3        1004 2014-01-04     Company D     New York    Andrew Cencini   East
# 4        1005 2014-01-04     Company D     New York    Andrew Cencini   East
# ..        ...        ...           ...          ...               ...    ...
# 384      1067 2014-03-08     Company H     Portland   Nancy Freehafer  North
# 385      1070 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 386      1071 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 387      1075 2014-03-10     Company J      Chicago    Laura Giussani   East
# 388      1077 2014-03-10     Company J      Chicago    Laura Giussani   East
#
# ...

# %%
for i in df:
    
    if df[i].dtypes=="object":
        print(i)
        print(df[i].unique())
# Out:
# Customer Name
# ['Company AA' 'Company D' 'Company L' 'Company H' 'Company CC' 'Company C'
#  'Company F' 'Company BB' 'Company J' 'Company G' 'Company K' 'Company A'
#  'Company I' 'Company Y' 'Company Z']
# City
# ['Las Vegas' 'New York' 'Portland' 'Denver' 'Los Angelas' 'Milwaukee'
#  'Memphis' 'Chicago' 'Boise' 'Miami' 'Seattle' 'Salt Lake City']
# Salesperson
# ['Mariya Sergienko' 'Andrew Cencini' 'Nancy Freehafer' 'Jan Kotas'
#  'Michael Neipper' 'Anne Larsen' 'Laura Giussani' 'Robert Zare']
# Region
# ['West' 'East' 'North' 'South']
# Shipper Name
# ['Shipping Company B' 'Shipping Company A' 'Shipping Company C']
# Ship Name
# ['Karen Toh' 'Christina Lee' 'John Edwards' 'Elizabeth Andersen'
#  'Soo Jung Lee' 'Thomas Axerr' 'Francisco Pérez-Olaeta' 'Amritansh Raghav'
#  'Roland Wacker' 'Ming-Yang Xie' 'Peter Krschne' 'Anna Bedecs'
#  'Sven Mortensen' 'John Rodman' 'Run Liu']
# Payment Type
# ['Check' 'Credit Card' 'Cash']
# Product Name
# ...

# %%
df["sales"]=df["Unit Price"]*df["Quantity"]
df
# Out:
#      Order_ID Order_Date Customer Name         City       Salesperson Region  \
# 0        1001 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 1        1002 2014-01-27    Company AA    Las Vegas  Mariya Sergienko   West
# 2        1003 2014-01-04     Company D     New York    Andrew Cencini   East
# 3        1004 2014-01-04     Company D     New York    Andrew Cencini   East
# 4        1005 2014-01-04     Company D     New York    Andrew Cencini   East
# ..        ...        ...           ...          ...               ...    ...
# 384      1067 2014-03-08     Company H     Portland   Nancy Freehafer  North
# 385      1070 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 386      1071 2014-03-03     Company C  Los Angelas  Mariya Sergienko   West
# 387      1075 2014-03-10     Company J      Chicago    Laura Giussani   East
# 388      1077 2014-03-10     Company J      Chicago    Laura Giussani   East
#
# ...

# %%
# region wise sales
rs=df[["Region","sales"]].groupby("Region")[["sales"]].sum().sort_values(by="sales",ascending=False)
rs
# Out:
#             sales
# Region
# North   151413.36
# East    118459.81
# South    98435.33
# West     96801.93

# %%
# payment wise sales
ps=df[["Payment Type","sales"]].groupby("Payment Type")[["sales"]].sum().sort_values(by="sales",ascending=False)
ps
# Out:
#                   sales
# Payment Type
# Credit Card   184844.35
# Cash          155333.30
# Check         124932.79

# %%
# product wise sales
prod_sales=df[["Product Name","sales"]].groupby("Product Name")[["sales"]].sum().sort_values(by="sales",ascending=False)[:5]
prod_sales
# Out:
#                  sales
# Product Name
# Curry Sauce   75320.00
# Coffee        74406.64
# Marmalade     47628.00
# Mozzarella    35704.80
# Crab Meat     26661.60

# %%
# category wise sales
cat_sales=df[["Category","sales"]].groupby("Category")[["sales"]].sum().sort_values(by="sales",ascending=False)
cat_sales
# Out:
#                          sales
# Category
# Beverages            111472.00
# Sauces                75320.00
# Jams, Preserves       57778.00
# Dairy Products        35704.80
# Canned Meat           26661.60
# Dried Fruit & Nuts    26532.31
# Pasta                 24897.00
# Baked Goods & Mixes   21951.90
# Condiments            20448.00
# Candy                 18860.84
# Soups                 17765.65
# Oil                   15393.35
# Fruit & Veg            6942.00
# Grains                 3143.00
# Shipping               2240.00

# %%
# citywise sales
city_sales=df[["City","sales"]].groupby("City")[["sales"]].sum().sort_values(by="sales",ascending=False)
city_sales
# Out:
#                    sales
# City
# New York        76281.30
# Portland        57917.37
# Miami           54348.33
# Memphis         44087.00
# Chicago         42178.51
# Milwaukee       39452.00
# Seattle         36839.99
# Salt Lake City  33985.90
# Los Angelas     30319.63
# Denver          18178.09
# Boise           17204.00
# Las Vegas       14318.32

# %%
# shipper name wise sales
shipper_sales=df[["Shipper Name","sales"]].groupby("Shipper Name")[["sales"]].sum().sort_values(by="sales",ascending=False)
shipper_sales
# Out:
#                         sales
# Shipper Name
# Shipping Company C  203450.80
# Shipping Company A  131162.13
# Shipping Company B  130497.51

# %%
# shipper name wise sales
cust_sales=df[["Customer Name","sales"]].groupby("Customer Name")[["sales"]].sum().sort_values(by="sales",ascending=False)
cust_sales
# Out:
#                   sales
# Customer Name
# Company D      76281.30
# Company H      57917.37
# Company BB     44087.00
# Company F      39452.00
# Company A      36839.99
# Company I      33985.90
# Company Z      32411.25
# Company C      30319.63
# Company J      29756.51
# Company K      21937.08
# Company CC     18178.09
# Company G      17204.00
# Company L      12994.64
# Company Y      12422.00
# Company AA      1323.68

# %%
# mont wise sales

month_sales=df[["month","sales"]].groupby("month")[["sales"]].sum()
month_sales
# Out:
#           sales
# month
# 1      32103.27
# 2      25837.75
# 3      55849.20
# 4      20771.79
# 5      34307.05
# 6      55601.61
# 7      27318.54
# 8      29921.46
# 9      31949.97
# 10     53033.59
# 11     31773.43
# 12     66642.78

# %%
quarter_sales=df[["Quarter","sales"]].groupby("Quarter")[["sales"]].sum()
quarter_sales
# Out:
#              sales
# Quarter
# 1        113790.22
# 2        110680.45
# 3         89189.97
# 4        151449.80
